# %%
import numpy as np
import pandas as pd

df_cons = pd.read_csv('/home/daver/Downloads/Pandas-Project-Exercise-main/constituents.csv')
df_fina = pd.read_csv('/home/daver/Downloads/Pandas-Project-Exercise-main/constituents-financials.csv')

# %%
df_cons.columns
df_fina.columns
df_cons.dtypes
df_fina.dtypes
# Out:
# Symbol             object
# Price             float64
# Price/Earnings    float64
# Dividend Yield    float64
# Earnings/Share    float64
# 52 Week Low       float64
# 52 Week High      float64
# Market Cap          int64
# EBITDA            float64
# Price/Sales       float64
# Price/Book        float64
# SEC Filings        object
# dtype: object

# %%
#first 5 rows of each dataset
df_cons.head(5)
# Out:
#   Symbol                 Name                  Sector
# 0    MMM           3M Company             Industrials
# 1    AOS      A.O. Smith Corp             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV          AbbVie Inc.             Health Care
# 4    ACN        Accenture plc  Information Technology

# %%
df_fina.head(5)
# Out:
#   Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    MMM  222.89           24.31        2.332862            7.92       259.77
# 1    AOS   60.24           27.76        1.147959            1.70        68.39
# 2    ABT   56.27           22.51        1.908982            0.26        64.60
# 3   ABBV  108.48           19.41        2.499560            3.29       125.86
# 4    ACN  150.51           25.47        1.714470            5.44       162.60
#
#    52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0       175.490  138721055226  9.048000e+09     4.390271       11.34
# 1        48.925   10783419933  6.010000e+08     3.575483        6.35
# 2        42.280  102121042306  5.744000e+09     3.740480        3.19
# 3        60.050  181386347059  1.031000e+10     6.291571       26.14
# 4       114.820   98765855553  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# ...

# %%
#Delete the last column of financial dataset
df_fina = df_fina.drop('SEC Filings',axis=1)

# %%
df_fina = df_fina.set_index('Symbol')

# %%
df_fina[['Market Cap']].sort_values(by = 'Market Cap', ascending = False).iloc[0:10]
# Out:
#           Market Cap
# Symbol
# AAPL    809508034020
# GOOGL   733823966137
# GOOG    728535558140
# MSFT    689978437468
# AMZN    685873374731
# FB      523423036576
# JPM     386613611000
# JNJ     353062464971
# XOM     326148660000
# BAC     321478200969

# %%
df_fina.sort_values(by = 'Market Cap', ascending = False).iloc[0:10]
# Out:
#           Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# AAPL     155.15           16.86        1.579541            9.20     180.1000
# GOOGL   1007.71           31.48        0.000000           22.27    1198.0000
# GOOG    1001.52           40.29        0.000000           22.27    1186.8900
# MSFT      85.01           25.76        1.874791            2.97      96.0700
# AMZN    1350.50          296.16        0.000000            6.16    1498.0000
# FB       171.58           27.90        0.000000            5.39     195.3200
# JPM      107.88           15.43        1.984584            6.30     117.3529
# JNJ      126.36           17.31        2.556688            0.39     148.3200
# XOM       76.07           21.37        4.003120            1.88      89.3000
# BAC       29.74           16.34        1.536000            1.55      32.6700
#
#         52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# Symbol
# ...

# %%
df_fina = df_fina.drop('GOOG',axis=0)

# %%
df_fina
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
# Cuales compañias tienen una rentabilidad por dividendo mayor a 4%
df_fina['Dividend Yield']>4
# Out:
# Symbol
# MMM     False
# AOS     False
# ABT     False
# ABBV    False
# ACN     False
#         ...
# XYL     False
# YUM     False
# ZBH     False
# ZION    False
# ZTS     False
# Name: Dividend Yield, Length: 504, dtype: bool

# %%
#Cuántas compañias tienen una rentabilidad por dividendo mayor a 4% (respuesta es 37)
import collections
collections.Counter(df_fina['Dividend Yield']>4)
# Out:
# Counter({False: 467, True: 37})

# %%
from math import e
df_1 = df_fina[df_fina['Market Cap']>(1*e**11)].loc[:,['Earnings/Share']]
# Out:
#         Earnings/Share
# Symbol
# MMM               7.92
# AOS               1.70
# ABT               0.26
# ABBV              3.29
# ACN               5.44
# ...                ...
# XYL               1.83
# YUM               4.07
# ZBH               9.01
# ZION              2.60
# ZTS               1.65
#
# [504 rows x 1 columns]

# %%
import numpy as np
my_new_list = []
for x,y in df_1.iterrows():
    my_new_list.append(y[0])

# %%
my_array = np.array((my_new_list))

# %%
len(my_array)
# Out:
# 504

# %%
np.mean(my_array)
# Out:
# 3.7170039682539686

# %%
df_fina['Earnings/Share']>0
# Out:
# Symbol
# MMM     True
# AOS     True
# ABT     True
# ABBV    True
# ACN     True
#         ...
# XYL     True
# YUM     True
# ZBH     True
# ZION    True
# ZTS     True
# Name: Earnings/Share, Length: 504, dtype: bool

# %%
from collections import Counter
Counter(df_fina['Earnings/Share']>0)
# Out:
# Counter({True: 452, False: 52})

# %%
df_fina
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
df_fina[['Dividend Yield']].max()
# Out:
# Dividend Yield    12.661196
# dtype: float64

# %%
max_dividend = df_fina.sort_values(by = 'Dividend Yield', ascending = False).iloc[0:1]
print(max_dividend)
# Out:
#         Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# CTL      16.2            8.35       12.661196            1.16        27.61
#
#         52 Week High   Market Cap        EBITDA  Price/Sales  Price/Book
# Symbol
# CTL           13.161  18237196861  5.577000e+09     1.479598        1.39

# %%
max_dividend['52 Week High']
# Out:
# Symbol
# CTL    13.161
# Name: 52 Week High, dtype: float64
